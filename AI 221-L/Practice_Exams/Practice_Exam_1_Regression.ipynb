# %% [markdown]
# # Practice Exam 1: Real Estate Price Prediction (Regression)
# **Objective:** Build models to predict continuous housing prices from scratch.
#
# **Models to implement:** Linear Regression, Decision Tree Regressor, Random Forest Regressor.
#
# *Run the cell below to load the corrupted dataset.*

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing

# Load dataset
data = fetch_california_housing()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['Target_Price'] = data.target

# Artificially inject missing values in 'HouseAge' and 'AveRooms' for practice
np.random.seed(42)
df.loc[np.random.choice(df.index, 500), 'HouseAge'] = np.nan
df.loc[np.random.choice(df.index, 300), 'AveRooms'] = np.nan

df.head()

# %% [markdown]
# ## Task: The MLOps Pipeline Approach
# Instead of doing EDA, imputation, and scaling manually line-by-line, build an **`sklearn.pipeline.Pipeline`** that automatically imputes missing values with the median, scales the features with `StandardScaler`, and trains the models!

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# Your Pipeline code goes here!
