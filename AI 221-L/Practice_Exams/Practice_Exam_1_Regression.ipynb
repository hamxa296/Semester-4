# %% [markdown]
# # Practice Exam 1: Real Estate Price Prediction (Regression)
# **Objective:** Build models to predict continuous housing prices from scratch.
#
# **Models to implement:** Linear Regression, Decision Tree Regressor, Random Forest Regressor.
#
# *Run the cell below to load the corrupted dataset, then write your own code to perform EDA, preprocessing, model training, and evaluation.*

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing

# Load dataset
data = fetch_california_housing()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['Target_Price'] = data.target

# Artificially inject missing values in 'HouseAge' and 'AveRooms' for practice
np.random.seed(42)
df.loc[np.random.choice(df.index, 500), 'HouseAge'] = np.nan
df.loc[np.random.choice(df.index, 300), 'AveRooms'] = np.nan

df.head()

# %%
# Your complete pipeline goes here (EDA -> Split -> Impute -> Scale -> Train -> Evaluate)

# %% [markdown]
# ## Bonus Challenge: Custom Prediction Function
# Write a Python function called `predict_house_price(input_data)` that takes a raw dictionary of features, loads a saved Scaler and Model using `joblib`, scales the features, and returns the predicted price.

# %%
import joblib

# Your custom prediction function goes here!
